# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomésticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas últimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
# * Método que calcula la media de ventas de los últimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
'''
Generamos una clase llamada Tienda con dos atributos generales. 
Después, generamos un construcor con otros atributos específicos.

Comenzamos implementando los métodos que pide el elercicio:
--> calcular_ventas_totales: que hace un sumatorio de los elementos introducidos en la funcion
--> media_ventas_empleado: genero una variable con la funcion anterior. Calculo la media con esa variable.
--> ubicacion: gereno una variable con un string que llama con claves a otras variables
--> ventas_ultimo_mes: coge el ultimo importe de las ventas con -1, considerando éste el último mes
'''
# 1. Implementar la clase "Tienda"
class Tienda:
    tipo_tienda = "Electrodomésticos"
    abierto = True
    pass
    def __init__(self,nombre_tienda,direccion_tienda,numero_empleados,ventas_meses):
        self.nombre = str(nombre_tienda)
        self.direccion = str(direccion_tienda)
        self.empleados = int(numero_empleados)
        self.ventas= list(ventas_meses)
# Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
    def calcular_ventas_totales(self):
        total = sum(self.ventas)
        return total
# Método que calcula la media de ventas de los últimos meses, por empleado
    def media_ventas_empleado(self):
        ventas_totales = self.calcular_ventas_totales()
        media = ventas_totales / self.empleados
        return media
# Método que devuelve en un string el nombre de la tienda, junto con su dirección. 
    def ubicacion(self):
        str_ubicacion = f"Tienda: {self.nombre} | Dirección: {self.direccion}"
        return str_ubicacion
# Método que obtiene las ventas del último mes.
    def ventas_ultimo_mes(self):
        return self.ventas[-1]

# %%
# 2 Crear 3 tiendas con datos inventados
tienda_1 = Tienda("Tienda_1","Calle Zabalburu,10",300, [1000,2000,5000])
tienda_2 = Tienda("Tienda_2", "Avenida Lehendakari Aguirre,52",600,[6000,2000,4000])
tienda_3 = Tienda("Tienda_3", "Autonomía,45",5000,[5000,4000,12000])

# %%
print(tienda_1.calcular_ventas_totales()) # Método ventas_totales
print(round(tienda_1.media_ventas_empleado(),2)) # Método media_ventas_empleado
print(tienda_1.ubicacion()) # Método que devuelve el nombre de la tienda y su dirección. 
print(tienda_1.ventas_ultimo_mes()) # Metodo que obtiene las ventas del último mes.
# Out:
# 8000
# 26.67
# Tienda: Tienda_1 | Dirección: Calle Zabalburu,10
# 5000

# %%
# 3. Comprueba todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
print(f"La tienda {tienda_1.nombre} tiene los siguientes datos:")
print(f"\tNombre: {tienda_1.nombre}")
print(f"\tDirección: {tienda_1.direccion}")
print(f"\tEmpleados: {tienda_1.empleados}")
print("-" * 30) # Separador para mejor lectura
print(f"\tVentas Totales: {tienda_1.calcular_ventas_totales()}")
print(f"\tMedia Ventas por Empleado: {round(tienda_1.media_ventas_empleado(), 2)}")
print(f"\tUbicación (Método): {tienda_1.ubicacion()}")
print(f"\tVentas Último Mes: {tienda_1.ventas_ultimo_mes()}")
# Out:
# La tienda Tienda_1 tiene los siguientes datos:
# 	Nombre: Tienda_1
# 	Dirección: Calle Zabalburu,10
# 	Empleados: 300
# ------------------------------
# 	Ventas Totales: 8000
# 	Media Ventas por Empleado: 26.67
# 	Ubicación (Método): Tienda: Tienda_1 | Dirección: Calle Zabalburu,10
# 	Ventas Último Mes: 5000

# %%
# Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
direccion = ["Calle Zabalburu","Avenida Lehendakari Aguirre,52","Autonomía,45"]
for direccion in direccion:
    if "Avenida" in direccion:
        print(direccion)
# Out:
# Avenida Lehendakari Aguirre,52

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
# Implementa la clase *Perro*
class Perro:
    patas = 4
    orejas = 2
    ojos = 2
    velocidad = 0
# Cuando se inicialice:
    def __init__(self,raza,pelo="Marron", dueño=None):
        self.raza = raza
        self.pelo = pelo
        self.dueño = dueño
        self.velocidad_actual = Perro.velocidad
# Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
    def andar(self, aumento_velocidad):
        self.velocidad_actual += aumento_velocidad  
# Necesita otro método (parar), donde pondremos la velocidad a 0.
    def parar(self):
        self.velocidad_actual = 0
# Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
    def ladrar (self,mensaje):
        return "GUAU!" + mensaje

# %%
# Crea un objeto de tipo *Perro*, sin dueño
mi_perro = Perro("Chow Chow")

# %%
# Comprueba que están bien todos sus atributos
print(mi_perro.raza)
print(mi_perro.pelo)
print(mi_perro.dueño)
print(mi_perro.velocidad_actual)
# Out:
# Chow Chow
# Marron
# None
# 0

# %%
# Prueba que ande, y comprueba su velocidad
mi_perro.andar(10)

print(mi_perro.velocidad_actual)
# Out:
# 10

# %%
#  Páralo
mi_perro.parar()

print(mi_perro.velocidad_actual)
# Out:
# 0

# %%
# Perro ladrando
mi_perro.ladrar("terminé!")
# Out:
# 'GUAU!terminé!'
