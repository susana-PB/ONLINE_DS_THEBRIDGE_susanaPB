# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
# import numpy as np
import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# Importamos dataset
titanic = pd.read_csv('data/titanic.csv')

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
# Directamene DataFrame
people = titanic[["name", "sex", "age"]].copy()
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
people2 = pd.DataFrame(titanic, columns=["name", "sex", "age"])
people2
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
# Con head: primeras 3 filas
people.head(3)
# Out:
#                              name     sex    age
# 0   Allen, Miss. Elisabeth Walton  female  29.00
# 1  Allison, Master. Hudson Trevor    male   0.92
# 2    Allison, Miss. Helen Loraine  female   2.00

# %%
# Con tail: últimas 4 filas
people.tail(4)
# Out:
#                            name     sex   age
# 1305      Zabour, Miss. Thamine  female   NaN
# 1306  Zakarian, Mr. Mapriededer    male  26.5
# 1307        Zakarian, Mr. Ortin    male  27.0
# 1308         Zimmerman, Mr. Leo    male  29.0

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic = titanic.iloc[3:10]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0     19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev = titanic.iloc[40:65]
s_titanic_rev
# Out:
#     pclass  survived                                               name  \
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 41       1         1          Brown, Mrs. James Joseph (Margaret Tobin)
# 42       1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43       1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44       1         1                    Burns, Miss. Elizabeth Margaret
# 45       1         0                  Butt, Major. Archibald Willingham
# 46       1         0                              Cairns, Mr. Alexander
# 47       1         1                  Calderhead, Mr. Edward Pennington
# 48       1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 49       1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50       1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 51       1         0                           Carlsson, Mr. Frans Olof
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
left_columns = titanic.iloc[:, :7]
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.iloc[:,2:5]
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.iloc[:,7:]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
# Name of the oldest person
oldest_person = titanic.loc[titanic['age'].idxmax(), 'name']
print('El nombre de la persona más mayor es:', oldest_person)

# Viajaba solo? o tenia algún falimiar viajendo con él?
if oldest_person in titanic['name'].values:
    family = titanic.loc[titanic['name'] == oldest_person, ['sibsp', 'parch']].values[0]
    if family[0] == 0 and family[1] == 0:
        print(f'{oldest_person} viajaba solo.')
    else:
        print(f'{oldest_person} no viajaba solo, tenía familiares a bordo.')
# Out:
# El nombre de la persona más mayor es: Barkworth, Mr. Algernon Henry Wilson
# Barkworth, Mr. Algernon Henry Wilson viajaba solo.

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %% [markdown]
# This list of numbers are random, could be different.

# %%
import random

# %%
rows = random.sample(range(len(titanic)),5)
rows
# Out:
# [197, 139, 623, 485, 227]

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols = random.sample(range(len(titanic.columns)),3)
cols
# Out:
# [7, 1, 4]

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
new_df = titanic.iloc[rows,cols]
new_df
# Out:
#             ticket  survived   age
# 197         113773         0  19.0
# 139       PC 17582         1  58.0
# 623         347082         0   6.0
# 485  SC/Paris 2163         0  36.0
# 227         113776         1  22.0

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe = titanic['sex'] == 'female'
array_fe
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
woman_titanic = titanic.rename(columns={'sex':'gender'})
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
minor_wo = titanic[(titanic['age'] < 18) & (titanic['sex'] == 'female')].shape[0]
minor_wo
# Out:
# 72

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_wo = titanic[(titanic['age'] < 18) & (titanic['sex'] == 'female') & (titanic['survived'] == 0) ].shape[0]
dead_wo
# Out:
# 22

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic_copy = titanic.copy()
titanic_clean = titanic_copy.dropna(how='any') # how=any Elimina la fila si al menos una columna tiene NaN
print(titanic_clean.shape)
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic_clean = titanic_copy.dropna(how='all') # how=all Elimina la fila solo si todas las columnas son NaN.
print(titanic_clean.shape)
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
more_1000 = titanic_copy.dropna(axis = 1,thresh=1000) # thresh= 1000 solo se mantendrán columnas que tengan al menos 1000 valores no nulos.
more_1000.shape
# Out:
# (1309, 10)

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
ratio = titanic['boat'].isnull().sum() / titanic.shape[0]
ratio
# Out:
# np.float64(0.6287242169595111)

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('pclass')[['age','fare']].agg(['mean','max'])
by_class
# Out:
#               age             fare
#              mean   max       mean       max
# pclass
# 1       39.159930  80.0  87.508992  512.3292
# 2       29.506705  70.0  21.179196   73.5000
# 3       24.816367  74.0  13.302889   69.5500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
by_class['age']['max']
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: max, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
by_class['fare']['mean']
# Out:
# pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: mean, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
counted = titanic[titanic['survived'] == 1].pivot_table(index='pclass',columns='sex',aggfunc='count')
counted
# Out:
#           age        boat        body       cabin      embarked       ...  \
# sex    female male female male female male female male   female male  ...
# pclass                                                                ...
# 1         128   53    138   61      0    0    116   51      137   61  ...
# 2          92   23     86   25      0    0     12    5       94   25  ...
# 3          72   59     94   73      0    0      5    4      106   75  ...
#
#          name       parch       sibsp      survived      ticket
# sex    female male female male female male   female male female male
# pclass
# 1         139   61    139   61    139   61      139   61    139   61
# 2          94   25     94   25     94   25       94   25     94   25
# 3         106   75    106   75    106   75      106   75    106   75
#
# [3 rows x 24 columns]

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted = titanic[titanic['survived'] == 1].pivot_table(index='pclass',columns='sex',values= 'age',aggfunc='count')
counted['total'] = counted['female'] + counted['male']
counted
# Out:
# sex     female  male  total
# pclass
# 1          128    53    181
# 2           92    23    115
# 3           72    59    131

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
sorted = counted.sort_values(by=['pclass','total'], ascending=True)
sorted
# Out:
# sex     female  male  total
# pclass
# 1          128    53    181
# 2           92    23    115
# 3           72    59    131

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
rows_mask = titanic[(titanic['sex'] == 'female') & (titanic['pclass'] == 3) & (titanic['age'] < 30) & (titanic['survived'] == 1)]
rows_mask
# Out:
#       pclass  survived                                               name  \
# 604        3         1                        Abelseth, Miss. Karen Marie
# 607        3         1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 612        3         1                         Aks, Mrs. Sam (Leah Rosen)
# 621        3         1    Andersen-Jensen, Miss. Carla Christine Nielsine
# 625        3         1                    Andersson, Miss. Erna Alexandra
# 643        3         1                     Asplund, Miss. Lillian Gertrud
# 653        3         1                               Ayoub, Miss. Banoura
# 657        3         1                             Baclini, Miss. Eugenie
# 658        3         1                      Baclini, Miss. Helene Barbara
# 659        3         1                     Baclini, Miss. Marie Catherine
# 660        3         1              Baclini, Mrs. Solomon (Latifa Qurban)
# 661        3         1                         Badman, Miss. Emily Louisa
# ...

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
rows_loc = titanic.loc[(titanic['sex'] == 'male') & (titanic['pclass'] > 1) & (titanic['age'] < 50) & (titanic['survived'] == 0)]
rows_loc
# Out:
#       pclass  survived                            name   sex   age  sibsp  \
# 323        2         0             Abelson, Mr. Samuel  male  30.0      1
# 325        2         0  Aldworth, Mr. Charles Augustus  male  30.0      0
# 326        2         0      Andrew, Mr. Edgardo Samuel  male  18.0      0
# 327        2         0        Andrew, Mr. Frank Thomas  male  25.0      0
# 328        2         0            Angle, Mr. William A  male  34.0      1
# ...      ...       ...                             ...   ...   ...    ...
# 1299       3         0             Yasbeck, Mr. Antoni  male  27.0      1
# 1301       3         0            Youseff, Mr. Gerious  male  45.5      0
# 1306       3         0       Zakarian, Mr. Mapriededer  male  26.5      0
# 1307       3         0             Zakarian, Mr. Ortin  male  27.0      0
# 1308       3         0              Zimmerman, Mr. Leo  male  29.0      0
#
#       parch      ticket     fare cabin embarked boat   body  \
# ...

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
titanic['name'].nunique()
# Out:
# 1307

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
# El valor repetido es el que de True en la lista
repeated = titanic['name'].value_counts() > 1

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(titanic['age'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Distribución de edades en Titanic')
plt.xlabel('Edad')
plt.ylabel('Número de pasajeros')
plt.show()

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
# Contar cuántos hay de cada categoría
counts = titanic['sex'].value_counts()   

# Crear gráfico de barras
plt.bar(counts.index, counts.values, color=['skyblue', 'pink'])
plt.title('Distribución por género')
plt.xlabel('Género')
plt.ylabel('Número de pasajeros')
plt.show()

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
import seaborn as sns

# %%
sns.countplot(data=titanic, x='sex')  
plt.title('Distribución por género')
plt.xlabel('Género')
plt.ylabel('Número de pasajeros')
plt.show()

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](./img/catplotgen.png)

# %%
sns.catplot(data=titanic, x='sex')  
plt.title('Distribución por género')
plt.xlabel('Género')
plt.ylabel('Número de pasajeros')
plt.show()

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %%
ages_not_survived = titanic.loc[titanic['survived'] == 0, 'age'].dropna()
sns.kdeplot(
    data=ages_not_survived,
    color="red",
    label="Not Survived",
    shade=True)
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Distribución de edades de los pasajeros que no sobrevivieron")
plt.legend()
plt.show()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_8324\3496970345.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(
