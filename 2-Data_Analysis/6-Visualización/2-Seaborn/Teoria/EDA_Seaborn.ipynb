# %% [markdown]
# ![imagen](./img/seaborn.png)
#
#
# # Exploratory Data Analysis with Seaborn
# Entender cómo se hacen las gráficas en python está muy bien, pero lo importante es saber cuándo usarlas. En este notebook no se pretende explicar todos los tipos de gráficas que hay (histogramas, scatter plots, heatmaps...), en primer lugar porque es imposible abarcarlo todo, y en segundo lugar porque hay que ir un paso atrás antes de elegir la gráfica, ya que tenemos que comprender de qué tipo son los datos y qué es lo que estamos buscando con cada gráfica.
#
# Por tanto, primero tendremos que identificar el tipo de los datos y cuántas variables vamos a representar
# - Una variable numérica
# - Una variable categórica
# - Dos variables numéricas
# - Tres o más variables numéricas
# - Dos variables categóricas
# - Variables numéricas y categóricas
#
# Teniendo claro esto, junto con un buen catálogo de gráficas, lo tendremos mucho más fácil.
#
# https://www.data-to-viz.com/

# %% [markdown]
# # Tipos de las variables
# Antes de representar cualquier variable es imprescindible comprender qué tipo de datos queremos representar. Tenemos los siguientes:
#
# ![imagen](./img/dtypes.png)

# %%
# !pip install seaborn

# %%
# Importamos todos los paquetes que vayamos a necesitar
from sklearn.datasets import load_iris
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Algunas configuraciones de los paquetes
pd.set_option("display.max_rows", 500) # Cuántas filas de los DataFrames nos "escupe" pandas en el Notebook
sns.set_theme(color_codes=True)

import warnings
warnings.filterwarnings("ignore")

# %%
# Cargamos las features en un DataFrame:
iris_df = pd.DataFrame(load_iris()["data"],columns=load_iris()["feature_names"])
boston_df = pd.read_csv('data/boston_house_prices.csv', header=1)

# Y añadimos la columna de especies:
iris_df["target"] = load_iris()["target_names"][load_iris()["target"]]

# Cargamos tb el dataset del titanic
titanic_df = pd.read_csv("data/titanic.csv", sep="\t")

# Cargamos los datos del supermarket sales
market_df = pd.read_csv("data/supermarket_sales.csv")

# Cargamos dataset de suicidios
suicid_df = pd.read_csv("data/suicide.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
market_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
suicid_df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %% [markdown]
# ## 1. Análisis univariante
# ### 1.1 Variables cuantitativas
# Si queremos ver cómo se distribuyen los precios de venta de tickets del Titanic.
# #### Densidad
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)
#
# Este tipo de gráficas nos sirven para ver la distribución de los datos, donde se concentran más, ¿es dispersa? ¿tiene asimétría? ¿por qué? ¿Hay outliers?

# %%
titanic_df['Fare'].min()
# Out:
# np.float64(6.75)

# %%
titanic_df['Fare'].max()
# Out:
# np.float64(263.0)

# %%
plt.figure(figsize=(10,5))
# sns.distplot(titanic_df["Fare"], hist = False);
sns.displot(titanic_df["Fare"], kind="kde");
#plt.title("My KDE")
# plt.xlim(0,50)

# %% [markdown]
# #### Histograma
# También podemos verlo en un histograma
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)
#
# Los histogramas dan la frecuencia de aparición de todos los valores. Muy similar al diagrama de densidad anterior. La diferencia es que ahora el eje y es un conteo y no la probabilidad de aparición de los valores de la variable.

# %%
plt.figure(figsize=(10,5))
sns.displot(titanic_df["Fare"],
             kind="hist",
             color='g',
             bins=10);
# plt.xlim(0,30)
# plt.ylim(0,20)

# %% [markdown]
# Podemos agrupar (visualmente) una variable numérica. Podría ser una posible categorización de los billetes

# %%
plt.figure(figsize=(10,5))
sns.histplot(titanic_df["Fare"],
             kde=True,
            bins=10);

# %% [markdown]
# #### Histograma + Densidad
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
plt.figure(figsize=(10,5))
# sns.distplot(titanic_df["Fare"],
#             kde_kws={"color": "k", "lw": 3, "label": "KDE"},
#             hist_kws={"histtype": "step", "linewidth": 3,
#                       "alpha": 1, "color": "g"});
sns.histplot(
    data=titanic_df, 
    x="Fare",     
    kde=True,
    line_kws={"color": "black", "lw": 3, "label": "KDE"},
    element="step",
    fill=False, 
    linewidth=3,
    alpha=1, 
    color="green"
    );

# %% [markdown]
# Otra manera muy visual de ver la concentración de los valores es mediante el argumento `rug`

# %%
plt.figure(figsize=(10,5))
sns.displot(titanic_df["Fare"],
            rug=True,
            bins=100)
plt.xlim(0, 100);

# %% [markdown]
# #### Boxplot
#
# [Colores de Matplotlib](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)
#
# [Boxlot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)
#
# Los boxplots dan una información muy parecida a los gráficos vistos anteriormente, aunque en este caso destaca mucho más los outliers.

# %%
p_0 = np.percentile(titanic_df["Fare"], 0) #Q0 #Min
p_25 = np.percentile(titanic_df["Fare"], 25) #Q1
p_50 = np.percentile(titanic_df["Fare"], 50) #Q2 #Mediana
p_75 = np.percentile(titanic_df["Fare"], 75) #Q3
p_100 = np.percentile(titanic_df["Fare"], 100) #Q4 #Max

print("Valor del percentil 0:", p_0)
print("Valor del percentil 25:", p_25)
print("Valor del percentil 50:", p_50)
print("Valor del percentil 75:", p_75)
print("Valor del percentil 100:", p_100)
print("Valor media:", round(titanic_df["Fare"].mean(),2) )
# Out:
# Valor del percentil 0: 6.75
# Valor del percentil 25: 8.00315
# Valor del percentil 50: 14.4542
# Valor del percentil 75: 30.37185
# Valor del percentil 100: 263.0
# Valor media: 28.11

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=titanic_df["Fare"], color="sienna");
# plt.xlim(0,50)

# %% [markdown]
# ![imagen](./img/boxplot.png)

# %% [markdown]
# #### Violinplot
#
# [Colores de Matplotlib](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)
#
# [Violinplot](https://seaborn.pydata.org/generated/seaborn.violinplot.html)
#
# Igual que un diagrama de caja, pero en este caso tiene la función de distribución en lugar de la propia caja

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x=titanic_df["Fare"], color='deeppink');

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x=titanic_df["Fare"], color='lightseagreen', bw=.5, inner="stick");

# %% [markdown]
# ### 1.2 Variables cualitativas
# Para representar una variable categórica tendremos que ver su frecuencia de valores
#
# En este caso vamos a ver qué tipo de embarque ha sido el más frecuente.
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %%
titanic_df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
plt.figure(figsize=(7,5))
sns.countplot(x=titanic_df["Embarked"], hue=titanic_df["Embarked"]);
plt.title("Composición por puerto")
# Out:
# Text(0.5, 1.0, 'Composición por puerto')

# %% [markdown]
# #### Lollipop
#
# ¿Cuáles han sido los productos más pedidos?
#
# [Documentación](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hlines.html)

# %%
# conteo

# %%
market_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
market_df['Product line'].value_counts(ascending=False)
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
conteo = market_df['Product line'].value_counts(ascending=False)

plt.figure(figsize=(10,5))
plt.hlines(y=conteo.index,
           xmin=150,
           xmax=conteo,
           color='skyblue')
plt.plot(conteo, conteo.index, "o");

# %% [markdown]
# #### Donut chart/Pie chart
#
# [Documentación](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html)

# %%
titanic_df["Embarked"].value_counts()
# Out:
# Embarked
# S    110
# C     32
# Q     13
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
 
# create data
data = titanic_df["Embarked"].value_counts()
 
# # Create a circle for the center of the plot
my_circle=plt.Circle( (0,0),
                     0.9, # Grosor del donut
                     color='white')

plt.figure(figsize=(8,8))

plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%');

p=plt.gcf()
p.gca().add_artist(my_circle);

# %%
plt.figure(figsize=(8,8))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%')
p=plt.gcf();

# %% [markdown]
# ## 2. Análisis Bivariante
# ### 2.1 Comparativa de variables cuantitativas (2-4 variables)
# #### Boxplot
#
# En este ejemplo veremos cómo de diferentes son las distribuciones de las 4 características que definen a una flor.
#
# [Boxlot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
iris_df.columns.values[0:4]
# Out:
# array(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'], dtype=object)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=iris_df[iris_df.columns.values[0:4]]);

# %% [markdown]
# El boxplot está bien, pero hay algo de información que se nos escapa

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=iris_df[iris_df.columns.values[0:4]])
sns.swarmplot(data=iris_df[iris_df.columns.values[0:4]],
             color="black", edgecolor="gray");

# %% [markdown]
# #### Diagramas de densidad
#
# Otra manera de ver cómo se distribuyen las características de las flores.
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.kdeplot.html)

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data=iris_df[iris_df.columns.values[0:4]], shade=True);

# %% [markdown]
# #### Histogramas
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
plt.figure(figsize=(12,8))
sns.displot(iris_df[["sepal length (cm)", "sepal width (cm)"]], kde=True);
# sns.displot(iris_df["sepal width (cm)"] , color="red", label="Sepal Width")
# plt.legend();

# %%
# f, axes = plt.subplots(2, 2, figsize=(15,10), sharex=True)
# sns.distplot(iris_df["sepal length (cm)"] , color="skyblue", ax=axes[0, 0])
# sns.distplot(iris_df["sepal width (cm)"] , color="olive", ax=axes[0, 1])
# sns.distplot(iris_df["petal length (cm)"] , color="gold", ax=axes[1, 0])
# sns.distplot(iris_df["petal width (cm)"] , color="teal", ax=axes[1, 1]);

# Setup the figure and axes
f, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True)

# Update sns.distplot to sns.histplot with kde=True
sns.histplot(iris_df["sepal length (cm)"], color="skyblue", ax=axes[0, 0], kde=True)
sns.histplot(iris_df["sepal width (cm)"], color="olive", ax=axes[0, 1], kde=True)
sns.histplot(iris_df["petal length (cm)"], color="gold", ax=axes[1, 0], kde=True)
sns.histplot(iris_df["petal width (cm)"], color="teal", ax=axes[1, 1], kde=True)

plt.tight_layout()

# %% [markdown]
# #### Scatter plot
#
# En este ejemplo se ve claramente cómo estas dos variables sirven para distinguir las setosas de los otros tipos
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=iris_df['sepal length (cm)'],
                y=iris_df['sepal width (cm)'],
                hue = iris_df['target'],
               s=100);

# %% [markdown]
# [Documentación dataset](https://scikit-learn.org/stable/datasets/index.html#boston-dataset)
#
# [Documentación jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)
#
# % poblacion con poco poder adquisitivo vs media de habitaciones por vivienda

# %%
sns.jointplot(x=boston_df['LSTAT'],
              y=boston_df['RM'],
              color="#4CB391",
             height = 8);

# %%
sns.jointplot(x=boston_df['LSTAT'],
              y=boston_df['RM'],
              kind="hex",
              color="#4CB391");

# %%
plt.figure(figsize=(8,8))
sns.jointplot(x=boston_df['LSTAT'],
              y=boston_df['RM'],
              kind="kde",
              color="#4CB391");

# %% [markdown]
# ### 2.2 Comparativa de múltiples numéricas

# %% [markdown]
# #### Heatmaps
#
# Los heatmaps son perfectos para representar una matriz de correlación
#
# [Documentación heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %%
boston_df.corr().abs().round(2)["MEDV"].sort_values(ascending=False)
# Out:
# MEDV       1.00
# LSTAT      0.74
# RM         0.70
# PTRATIO    0.51
# INDUS      0.48
# TAX        0.47
# NOX        0.43
# CRIM       0.39
# AGE        0.38
# RAD        0.38
# ZN         0.36
# B          0.33
# DIS        0.25
# CHAS       0.18
# Name: MEDV, dtype: float64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(boston_df.corr().round(2),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %%
# EJEMPLO DE MALA ESCALA DE COLORES
f, ax = plt.subplots(figsize=(13, 10))
sns.heatmap(boston_df.corr(),
            annot=True,
            linewidths=.5,
            ax=ax,
            vmin=-1,
            vmax=1);

# %% [markdown]
# También nos permite comparar una variable numérica vs dos variables categóricas. Por ejemplo la cantidad de suicidios desagregado por edades y paises.
#
# Se recomienda que las dos variables categóricas tengan pocos casos, porque si no, no se va a ver bien el heatmap.

# %%
suicid_df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
data = suicid_df.groupby(['country', 'age']).sum()['suicides_no']
data
# Out:
# country     age
# Albania     15-24 years      546
#             25-34 years      427
#             35-54 years      591
#             5-14 years        61
#             55-74 years      264
#                            ...
# Uzbekistan  25-34 years     8578
#             35-54 years    10964
#             5-14 years      1376
#             55-74 years     3595
#             75+ years        617
# Name: suicides_no, Length: 605, dtype: int64

# %%
data = suicid_df.groupby(['country', 'age']).sum()['suicides_no'].unstack()
data = data.loc[['Italy', 'Spain', 'Portugal', 'Belgium', 'Czech Republic']]

# %%
data
# Out:
# age             15-24 years  25-34 years  35-54 years  5-14 years  \
# country
# Italy                8571.0      16115.0      39250.0       400.0
# Spain                7559.0      13373.0      30331.0       354.0
# Portugal             1505.0       2590.0       6535.0        85.0
# Belgium              4475.0       8731.0      24300.0       216.0
# Czech Republic       3596.0       5498.0      16885.0       174.0
#
# age             55-74 years  75+ years
# country
# Italy               43314.0    24410.0
# Spain               29807.0    18778.0
# Portugal             8189.0     5157.0
# Belgium             16887.0     8152.0
# Czech Republic      12042.0     5492.0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data,
            square=True,
            linewidths=.3,
            annot=True);

# %% [markdown]
# #### Correlograma
#
# [Documentación Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)
#
# Interesante gráfica para ver en un dataset qué variables presentan correlación lineal, así como sus distribuciones. NO realices esta gráfica con muchas variables porque no se va a ver bien. Hazlo por partes.

# %%
# plt.figure(figsize=(6,6))
sns.pairplot(iris_df);

# %%
sns.pairplot(iris_df,
             kind="scatter",
             hue="target",
             plot_kws=dict(s=80, edgecolor="white",
                           linewidth=2.5));

# %%
sns.pairplot(iris_df,
             kind="scatter",
             hue="target",
             diag_kind="hist");

# %% [markdown]
# ### 2.3 Comparativa de dos variables cualitativas
# #### Tabla
#
# [Documentacion](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html)
#
# Lo más sencillo, una tabla con la frecuencia de valores. Esto es factible cuando los elementos únicos por categoría no son muchos.

# %%
pd.crosstab(titanic_df["Embarked"],
            titanic_df["Sex"],
            margins = True)
# Out:
# Sex       female  male  All
# Embarked
# C             11    21   32
# Q              7     6   13
# S             37    73  110
# All           55   100  155

# %% [markdown]
# #### Diagrama de barras
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.catplot.html)
#
# En un diagrama de barras también se entiende la representación de dos variables cualitativas

# %%
sns.catplot(x="Embarked",
            hue="Sex",
            kind="count",
            edgecolor=".6",
            orient = "V",
            data=titanic_df);

# %% [markdown]
# Otra manera de visualizar dos o más variables categóricas

# %%
plt.figure(figsize=(30,10));
sns.catplot(x="Survived",
            col="Embarked",
            col_wrap=3,
            data=titanic_df,
            kind="count");

# %%
titanic_df.groupby(['Embarked','Sex'])['Survived'].sum()
# Out:
# Embarked  Sex
# C         female     8
#           male       4
# Q         female     7
#           male       0
# S         female    24
#           male      10
# Name: Survived, dtype: int64

# %%
sns.catplot(x="Sex",
            y="Survived",
            hue="Embarked",
            kind="bar",
            data=titanic_df,
            ci=None); # Para que elimine las barras de error

# %%
df_plot = titanic_df.groupby(['Embarked', 'Survived']).size().reset_index().pivot(columns='Embarked',
                                                                                  index='Survived',
                                                                                  values=0)
df_plot.plot(kind='bar', stacked=True);
#df_plot

# %% [markdown]
# ### 2.4 Cualitativa vs cuantitativa
# #### Time series
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.lineplot.html)
#
# Las series temporales tienen la particularidad de que son datos ordenados

# %%
suicid_df2 = suicid_df[suicid_df['country'].isin(['Spain', 'Germany', 'France'])]
suicid_df2 = suicid_df2.groupby(['country', 'year']).sum()
suicid_df2
suicid_df2.reset_index(inplace=True)
suicid_df2
# Out:
#     country  year                                                sex  \
# 0    France  1985  malemalemalemalefemalefemalemalefemalefemalefe...
# 1    France  1986  malemalemalemalefemalefemalefemalemalefemalefe...
# 2    France  1987  malemalemalemalefemalefemalefemalemalefemalefe...
# 3    France  1988  malemalemalemalefemalefemalefemalemalefemalefe...
# 4    France  1989  malemalemalemalefemalefemalemalefemalefemalefe...
# 5    France  1990  malemalemalemalefemalefemalemalefemalefemalefe...
# 6    France  1991  malemalemalemalefemalefemalemalefemalefemalefe...
# 7    France  1992  malemalemalemalefemalefemalefemalemalefemalefe...
# 8    France  1993  malemalemalemalefemalemalefemalefemalefemalefe...
# 9    France  1994  malemalemalemalefemalefemalemalefemalefemalefe...
# 10   France  1995  malemalemalemalefemalefemalemalefemalefemalefe...
# 11   France  1996  malemalemalemalefemalefemalefemalemalefemalefe...
# 12   France  1997  malemalemalemalefemalefemalefemalemalefemalefe...
# 13   France  1998  malemalemalemalefemalefemalemalefemalefemalefe...
# 14   France  1999  malemalemalemalefemalefemalefemalemalefemalefe...
# 15   France  2000  malemalemalemalefemalefemalefemalemalefemalefe...
# 16   France  2001  malemalemalemalefemalefemalefemalemalefemalefe...
# 17   France  2002  malemalemalemalefemalefemalefemalemalefemalefe...
# 18   France  2003  malemalemalemalefemalefemalefemalemalefemalefe...
# 19   France  2004  malemalemalemalefemalefemalefemalemalefemalefe...
# 20   France  2005  malemalemalemalefemalefemalefemalemalefemalefe...
# 21   France  2006  malemalemalemalefemalefemalefemalemalefemalefe...
# 22   France  2007  malemalemalemalefemalefemalefemalemalefemalefe...
# 23   France  2008  malemalemalemalefemalefemalefemalemalefemalefe...
# 24   France  2009  malemalemalemalefemalefemalefemalemalefemalefe...
# 25   France  2010  malemalemalemalefemalefemalefemalemalefemalefe...
# 26   France  2011  malemalemalemalefemalefemalefemalemalefemalefe...
# 60  413,630,538,018413,630,538,018413,630,538,0184...              135096
# 61  535,101,248,776535,101,248,776535,101,248,7765...              174204
# 62  575,598,537,070575,598,537,070575,598,537,0705...              186888
# 63  629,202,392,004629,202,392,004629,202,392,0046...              204060
# 64  523,649,481,762523,649,481,762523,649,481,7625...              169272
# 65  529,121,577,320529,121,577,320529,121,577,3205...              170676
# 66  612,939,685,081612,939,685,081612,939,685,0816...              197328
# 67  640,998,292,395640,998,292,395640,998,292,3956...              205992
# 68  588,692,045,455588,692,045,455588,692,045,4555...              188856
# 69  617,041,986,858617,041,986,858617,041,986,8586...              197676
# 70  633,194,118,900633,194,118,900633,194,118,9006...              201072
# 71  595,402,616,547595,402,616,547595,402,616,5475...              186456
# 72  625,975,838,926625,975,838,926625,975,838,9266...              194028
# 73  705,145,868,624705,145,868,624705,145,868,6247...              215088
# 74  906,853,273,138906,853,273,138906,853,273,1389...              272412
# 75  1,069,555,500,3721,069,555,500,3721,069,555,50...              316464
# 76  1,157,276,458,1521,157,276,458,1521,157,276,45...              337104
# 77  1,264,551,499,1851,264,551,499,1851,264,551,49...              362952
# 78  1,479,341,637,0111,479,341,637,0111,479,341,63...              417228
# 79  1,635,015,380,1081,635,015,380,1081,635,015,38...              454176
# 80  1,499,099,749,9311,499,099,749,9311,499,099,74...              413640
# 81  1,431,616,749,6401,431,616,749,6401,431,616,74...              394068
# 82  1,488,067,258,3251,488,067,258,3251,488,067,25...              409164
# 83  1,336,018,949,8061,336,018,949,8061,336,018,94...              361752
# 84  1,361,854,206,5491,361,854,206,5491,361,854,20...              369504
# 85  1,376,910,811,0411,376,910,811,0411,376,910,81...              374052
# 86  1,197,789,902,7741,197,789,902,7741,197,789,90...              325296
#
#                                            generation
# 0   G.I. GenerationG.I. GenerationSilentBoomersG.I...
# 1   G.I. GenerationG.I. GenerationSilentBoomersG.I...
# 2   G.I. GenerationG.I. GenerationSilentBoomersG.I...
# 3   G.I. GenerationG.I. GenerationSilentBoomersG.I...
# 4   G.I. GenerationG.I. GenerationSilentBoomersG.I...
# 5   G.I. GenerationG.I. GenerationSilentBoomersG.I...
# 6   G.I. GenerationSilentBoomersBoomersG.I. Genera...
# 7   G.I. GenerationSilentBoomersBoomersG.I. Genera...
# 8   G.I. GenerationBoomersSilentBoomersG.I. Genera...
# 9   G.I. GenerationSilentBoomersBoomersG.I. Genera...
# 10  G.I. GenerationSilentBoomersGeneration XG.I. G...
# 11  G.I. GenerationBoomersSilentGeneration XG.I. G...
# 12  G.I. GenerationBoomersSilentGeneration XG.I. G...
# 13  G.I. GenerationBoomersSilentGeneration XG.I. G...
# 14  G.I. GenerationSilentBoomersGeneration XG.I. G...
# 15  G.I. GenerationBoomersSilentGeneration XG.I. G...
# 16  SilentBoomersSilentGeneration XSilentSilentBoo...
# 17  SilentBoomersSilentGeneration XSilentSilentBoo...
# 18  SilentBoomersSilentGeneration XSilentBoomersSi...
# 19  SilentBoomersSilentGeneration XSilentBoomersSi...
# 20  SilentBoomersSilentGeneration XSilentSilentBoo...
# 21  SilentBoomersSilentGeneration XSilentSilentBoo...
# 22  SilentBoomersSilentGeneration XSilentSilentBoo...
# 23  SilentBoomersSilentGeneration XSilentSilentBoo...
# 24  SilentBoomersSilentGeneration XSilentSilentBoo...
# 25  SilentGeneration XSilentGeneration XSilentSile...
# 26  SilentGeneration XBoomersMillenialsSilentBoome...
# 27  SilentGeneration XBoomersMillenialsSilentBoome...
# 28  SilentGeneration XBoomersMillenialsSilentBoome...
# 29  SilentGeneration XBoomersMillenialsSilentBoome...
# 30  G.I. GenerationG.I. GenerationSilentG.I. Gener...
# 31  G.I. GenerationSilentBoomersG.I. GenerationBoo...
# 32  G.I. GenerationSilentG.I. GenerationBoomersBoo...
# 33  G.I. GenerationSilentBoomersG.I. GenerationBoo...
# 34  G.I. GenerationSilentBoomersG.I. GenerationBoo...
# 35  G.I. GenerationSilentBoomersG.I. GenerationGen...
# 36  G.I. GenerationSilentBoomersG.I. GenerationGen...
# 37  G.I. GenerationSilentBoomersG.I. GenerationGen...
# 38  G.I. GenerationSilentBoomersGeneration XG.I. G...
# 39  G.I. GenerationSilentBoomersG.I. GenerationGen...
# 40  G.I. GenerationSilentBoomersG.I. GenerationGen...
# 41  SilentSilentBoomersSilentGeneration XMillenial...
# 42  SilentSilentBoomersSilentGeneration XMillenial...
# 43  SilentSilentBoomersSilentGeneration XMillenial...
# 44  SilentSilentBoomersSilentGeneration XMillenial...
# 45  SilentSilentBoomersSilentGeneration XSilentMil...
# 46  SilentSilentBoomersSilentGeneration XMillenial...
# 47  SilentSilentBoomersGeneration XSilentMillenial...
# 48  SilentSilentBoomersSilentGeneration XMillenial...
# 49  SilentSilentBoomersGeneration XSilentMillenial...
# 50  SilentSilentGeneration XGeneration XSilentMill...
# 51  SilentBoomersGeneration XMillenialsSilentMille...
# 52  SilentBoomersGeneration XMillenialsSilentMille...
# 53  SilentBoomersGeneration XMillenialsSilentBoome...
# 54  SilentBoomersGeneration XMillenialsSilentMille...
# 55  SilentBoomersGeneration XMillenialsSilentBoome...
# 56  G.I. GenerationG.I. GenerationG.I. GenerationS...
# 57  G.I. GenerationG.I. GenerationSilentG.I. Gener...
# 58  G.I. GenerationG.I. GenerationSilentG.I. Gener...
# 59  G.I. GenerationG.I. GenerationG.I. GenerationS...
# 60  G.I. GenerationG.I. GenerationSilentG.I. Gener...
# 61  G.I. GenerationG.I. GenerationG.I. GenerationB...
# 62  G.I. GenerationSilentG.I. GenerationBoomersBoo...
# 63  G.I. GenerationSilentBoomersBoomersG.I. Genera...
# 64  G.I. GenerationSilentBoomersBoomersG.I. Genera...
# 65  G.I. GenerationSilentBoomersBoomersG.I. Genera...
# 66  G.I. GenerationSilentGeneration XBoomersG.I. G...
# 67  G.I. GenerationSilentBoomersGeneration XG.I. G...
# 68  G.I. GenerationSilentBoomersGeneration XG.I. G...
# 69  G.I. GenerationSilentGeneration XBoomersG.I. G...
# 70  G.I. GenerationSilentBoomersGeneration XG.I. G...
# 71  G.I. GenerationSilentBoomersGeneration XG.I. G...
# 72  SilentSilentBoomersGeneration XSilentMillenial...
# 73  SilentSilentBoomersGeneration XSilentMillenial...
# 74  SilentSilentBoomersGeneration XSilentMillenial...
# 75  SilentSilentBoomersGeneration XSilentMillenial...
# 76  SilentSilentBoomersGeneration XSilentSilentMil...
# 77  SilentSilentBoomersGeneration XSilentMillenial...
# 78  SilentSilentBoomersGeneration XSilentSilentMil...
# 79  SilentSilentBoomersGeneration XSilentSilentMil...
# 80  SilentSilentBoomersGeneration XSilentMillenial...
# 81  SilentSilentGeneration XGeneration XSilentSile...
# 82  SilentBoomersGeneration XMillenialsSilentBoome...
# 83  SilentBoomersGeneration XMillenialsSilentMille...
# 84  SilentBoomersGeneration XMillenialsSilentBoome...
# 85  SilentBoomersGeneration XMillenialsSilentMille...
# 86  SilentBoomersGeneration XMillenialsSilentBoome...

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=suicid_df2,
             x="year",
             y="suicides_no",
             hue="country",
            linewidth = 3);

# %% [markdown]
# #### Treemap
# Un treemap es una opción muy interesante para mostrar una variable numérica vs una categórica

# %%
suicid_df.groupby("country").sum()['suicides_no'].sort_values(ascending=False)[:30]
# Out:
# country
# Russian Federation    1209742
# United States         1034013
# Japan                  806902
# France                 329127
# Ukraine                319950
# Germany                291262
# Republic of Korea      261730
# Brazil                 226613
# Poland                 139098
# United Kingdom         136805
# Italy                  132060
# Mexico                 111139
# Thailand               110643
# Canada                 107561
# Kazakhstan             101546
# Spain                  100202
# Argentina               82219
# Hungary                 73891
# Romania                 72777
# Australia               70111
# Belgium                 62761
# Belarus                 59892
# Sri Lanka               55641
# Colombia                53080
# Netherlands             50833
# Austria                 50073
# Czech Republic          43687
# Cuba                    41418
# Chile                   40895
# Sweden                  37795
# Name: suicides_no, dtype: int64

# %%
#!pip install squarify

# %%
import squarify

data = suicid_df.groupby("country").sum()['suicides_no'].sort_values(ascending=False)[:10]

plt.figure(figsize=(15,10))
squarify.plot(sizes=data.values, label=data.index, alpha=.8 )
plt.axis('off')
plt.title("Suicidios por país")
plt.show()

# %% [markdown]
# Con este catplot obtenemos la dispersión de la variable Age, por cada grupo de la categoría.

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", data=titanic_df);

# %% [markdown]
# El equivalente con un diagrama de caja sería el siguiente

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
# titanic_df['Survived_string'] = np.where(titanic_df['Survived']==1, 'Superviviente', 'No superviviente')
# titanic_df.head()

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", kind="box", data=titanic_df,col="Embarked");

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", kind="violin", data=titanic_df);

# %%
sns.catplot(x="Survived", y="Age", hue="Sex", kind="violin", split=True, data=titanic_df);

# %%
sns.catplot(x="City", y="Total", kind="swarm", data=market_df);

# %%
sns.catplot(x="Survived",
            y="Fare",
            hue="Sex",
            col="Embarked",
            data=titanic_df,
            height=5,
            aspect=.8);

# %%
suicid_df2 = suicid_df[suicid_df['country'].isin(['Spain', 'Germany', 'France', 'Japan'])]

chart = sns.catplot(x="age",
            y="suicides/100k pop",
            hue="sex",
            col="country",
            data=suicid_df2,
            height=8,
            aspect=.8)
chart.set_xticklabels(rotation=45);

# %%
sns.catplot(x="Fare",
            y="Embarked",
            hue="Sex",
            kind="violin",
            col="Survived",
            bw=.1,
            height=8,
            aspect=.8,
            data=titanic_df);

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(
   data=titanic_df, x="Fare", hue="Embarked",
   fill=True, common_norm=False,
   alpha=.5, linewidth=0,
);

# %%
suicid_df2 = suicid_df[suicid_df['country'] == 'Spain']

plt.figure(figsize=(20,8))
sns.barplot(x="year",
            y="suicides_no",
            palette="Blues_d",
            data=suicid_df2,
           ci=None);

# %%
# Filter countries with 'gdp_per_capita > 10000
df1 = suicid_df.groupby('country').sum()['suicides_no']
df2 = suicid_df[suicid_df['gdp_per_capita ($)'] > 10000].groupby('country').sum()['suicides_no']
df1 = df1[df1.index.isin(df2.index)]

df_tot = pd.DataFrame({"Tot_suicide": df1, "Suicide_gdp": df2}).sort_values("Tot_suicide", ascending=False)[:20]
df_tot.reset_index(level=0, inplace=True)

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="Tot_suicide", y="country", data=df_tot,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="Suicide_gdp", y="country", data=df_tot,
            label="High gdp", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
sns.despine(left=True, bottom=True)

# %% [markdown]
# #### Bubble chart

# %%
suicid_df[suicid_df['country-year'] == 'Spain2002']
# Out:
#       country  year     sex          age  suicides_no  population  \
# 23732   Spain  2002    male    75+ years          498     1171341
# 23733   Spain  2002    male  55-74 years          688     3804296
# 23734   Spain  2002    male  35-54 years          752     5784305
# 23735   Spain  2002    male  25-34 years          414     3566812
# 23736   Spain  2002  female    75+ years          154     1934508
# 23737   Spain  2002    male  15-24 years          196     2855801
# 23738   Spain  2002  female  55-74 years          268     4260724
# 23739   Spain  2002  female  35-54 years          245     5794565
# 23740   Spain  2002  female  25-34 years          103     3417162
# 23741   Spain  2002  female  15-24 years           46     2719911
# 23742   Spain  2002    male   5-14 years            7     2069866
# 23743   Spain  2002  female   5-14 years            1     1961320
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 23732              42.52    Spain2002           NaN    705,145,868,624
# 23733              18.08    Spain2002           NaN    705,145,868,624
# 23734              13.00    Spain2002           NaN    705,145,868,624
# 23735              11.61    Spain2002           NaN    705,145,868,624
# 23736               7.96    Spain2002           NaN    705,145,868,624
# 23737               6.86    Spain2002           NaN    705,145,868,624
# 23738               6.29    Spain2002           NaN    705,145,868,624
# 23739               4.23    Spain2002           NaN    705,145,868,624
# 23740               3.01    Spain2002           NaN    705,145,868,624
# 23741               1.69    Spain2002           NaN    705,145,868,624
# 23742               0.34    Spain2002           NaN    705,145,868,624
# 23743               0.05    Spain2002           NaN    705,145,868,624
#
#        gdp_per_capita ($)    generation
# 23732               17924        Silent
# 23733               17924        Silent
# 23734               17924       Boomers
# 23735               17924  Generation X
# 23736               17924        Silent
# 23737               17924    Millenials
# 23738               17924        Silent
# 23739               17924       Boomers
# 23740               17924  Generation X
# 23741               17924    Millenials
# 23742               17924    Millenials
# 23743               17924    Millenials

# %%
suicid_df2 = suicid_df[suicid_df['country-year'] == 'Spain2002']

sns.relplot(data=suicid_df2,
            x="suicides_no",
            y="suicides/100k pop",
            hue="sex", size="age",
            sizes=(4, 300),
            alpha=.5, palette="muted",
            height=6);

# %%
suicid_df2

# %% [markdown]
# ####
