# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = 
'''
Optimización de la experiencia de las personas en la organización: 
Análisis de Satisfacción, Burnout y Retención.
'''

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema =
'''
Exploración de cómo la satisfacción del personal influye directamente en el riesgo de burnout 
y la retención de talento, y cómo las acciones de engagement y bienestar impactan positivamente 
en estas métricas. 
Se utilizan Python y Tableau para analizar patrones y generar dashboards estratégicos que apoyan 
la toma de decisiones orientada a mejorar la experiencia de la persona.
'''

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = 
'''
La satisfacción del personal influye directamente en el riesgo de burnout y en la retención 
de talento. Una experiencia positiva fortalece la cultura organizacional y contribuye 
a entornos más saludables y sostenibles. Además, las acciones de engagement y bienestar incrementan 
la satisfacción y, a través de ella, reducen el burnout y mejoran la permanencia en la organización. 
Este análisis conecta métricas de experiencia, bienestar y cultura con decisiones estratégicas basadas 
en datos dentro de People Analytics.
'''

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# Parto de una unica dataset que contiene la información que necesito
df = pd.DataFrame()
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
fuente = "IBM HR Analytics Employee Attrition & Performance Dataset - Kaggle"

print("Fuente ->", fuente)
# Out:
# Fuente -> IBM HR Analytics Employee Attrition & Performance Dataset - Kaggle

# %%
'''
Este dataset no contiene directamente todas las variables que quiero analizar, 
y busco medir conceptos estratégicos que no siempre se registran explícitamente. 
En mi hipótesis analizaré: 
    -> La satisfacción de la persona 
    -> El riesgo de burnout 
    -> La retención de talento 
    -> La cultura organizacional 
Si no genero esas variables, no voy a poder mostrar como la satisfacción influye en el burnout 
y la retención, ni cómo la experiencia y cultura impactan decisiones estratégicas. 
Puedo crear indicadores derivados (proxies) que representen esos conceptos de manera cuantificable. 
Proxy = variable que aproxima un concepto que no se mide directamente.
'''
# Out:
# '\nEste dataset no contiene directamente todas las variables que quiero analizar, \ny busco medir conceptos estratégicos que no siempre se registran explícitamente. \nEn mi hipótesis analizaré: \n    -> La satisfacción del empleado \n    -> El riesgo de burnout \n    -> La retención de talento \n    -> La cultura organizacional \nSi no genero esas variables, no voy a poder mostrar como la satisfacción influye en el burnout \ny la retención, ni cómo la experiencia y cultura impactan decisiones estratégicas. \nPuedo crear indicadores derivados (proxies) que representen esos conceptos de manera cuantificable. \nProxy = variable que aproxima un concepto que no se mide directamente.\n'

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...
